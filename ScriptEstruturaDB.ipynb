-- %% [markdown]
-- # [TesteTecnicoMTP]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [TesteTecnicoMTP]    Script Date: 04/03/2024 14:16:10 ******/
CREATE DATABASE [TesteTecnicoMTP]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'TesteTecnicoMTP', FILENAME = N'C:\Users\lidia\TesteTecnicoMTP.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'TesteTecnicoMTP_log', FILENAME = N'C:\Users\lidia\TesteTecnicoMTP_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [TesteTecnicoMTP] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [TesteTecnicoMTP].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [TesteTecnicoMTP] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET ARITHABORT OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [TesteTecnicoMTP] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [TesteTecnicoMTP] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET  DISABLE_BROKER 
GO
ALTER DATABASE [TesteTecnicoMTP] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [TesteTecnicoMTP] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [TesteTecnicoMTP] SET  MULTI_USER 
GO
ALTER DATABASE [TesteTecnicoMTP] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [TesteTecnicoMTP] SET DB_CHAINING OFF 
GO
ALTER DATABASE [TesteTecnicoMTP] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [TesteTecnicoMTP] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [TesteTecnicoMTP] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [TesteTecnicoMTP] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [TesteTecnicoMTP] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
USE [TesteTecnicoMTP]
GO

-- %%
/****** Object:  Table [dbo].[__EFMigrationsHistory]    Script Date: 04/03/2024 14:16:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__EFMigrationsHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tarefas]

-- %%
/****** Object:  Table [dbo].[Tarefas]    Script Date: 04/03/2024 14:16:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tarefas](
	[Id] [uniqueidentifier] NOT NULL,
	[Descricao] [nvarchar](255) NOT NULL,
	[DataCadastro] [datetime2](7) NOT NULL,
	[Concluido] [bit] NOT NULL,
	[Ativo] [bit] NOT NULL,
	[DataAtualizacao] [datetime2](7) NULL,
 CONSTRAINT [PK_Tarefas] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Tarefas__DataCad__29572725]

-- %%
ALTER TABLE [dbo].[Tarefas] ADD  DEFAULT ('2024-03-02T05:09:14.9111436Z') FOR [DataCadastro]
GO

-- %% [markdown]
-- # [DF__Tarefas__Conclui__2A4B4B5E]

-- %%
ALTER TABLE [dbo].[Tarefas] ADD  DEFAULT (CONVERT([bit],(0))) FOR [Concluido]
GO

-- %% [markdown]
-- # [DF__Tarefas__Ativo__286302EC]

-- %%
ALTER TABLE [dbo].[Tarefas] ADD  DEFAULT (CONVERT([bit],(1))) FOR [Ativo]
GO

-- %% [markdown]
-- # [TesteTecnicoMTP]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [TesteTecnicoMTP] SET  READ_WRITE 
GO
